# %%
boat_side = "Right"

missionaries_on_right = 3
cannibals_on_right = 3

missionaries_on_left = 0
cannibals_on_left = 0

print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|-----B|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
missionaries = int(input("Enter missionaries: "))
cannibals = int(input("Enter cannibals: "))

# %%
missionaries = int(input("Enter missionaries: "))
cannibals = int(input("Enter cannibals: "))

# %%
missionaries_on_right -= missionaries
cannibals_on_right -= cannibals

missionaries_on_left += missionaries
cannibals_on_left += cannibals

# %%
print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|B-----|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
boat_side = "Left"

# %%
boat_side = "Right"

missionaries_on_right = 3
cannibals_on_right = 3

missionaries_on_left = 0
cannibals_on_left = 0

# %%
print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|-----B|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
boat_side = "Right"

missionaries_on_right = 3
cannibals_on_right = 3

missionaries_on_left = 0
cannibals_on_left = 0

# %%
print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|-----B|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
missionaries = int(input("Enter Number of Missionaries: "))
cannibals = int(input("Enter Number of Cannibals: "))

# %%
missionaries_on_right -= missionaries
cannibals_on_right -= cannibals

missionaries_on_left += missionaries
cannibals_on_left += cannibals

# %%
print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|B-----|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
boat_side = "Left"

# %%
for i in range(1):
# Out:
#   File "/tmp/ipykernel_478/4251007072.py", line 1
#     for i in range(1):
#                       ^
# SyntaxError: incomplete input

# %%
if boat_side == "Right":
    print("Boat is on right side....")
else:
    print("Boat is on Left side......")

# %%
missionaries = int(input("Enter Number of Missionaries: "))
cannibals = int(input("Enter Number of Cannibals: "))

# %%
missionaries_on_left -= missionaries
cannibals_on_left -= cannibals

missionaries_on_right += missionaries
cannibals_on_right += cannibals

# %%
print("M =", missionaries_on_left,
      "C =", cannibals_on_left,
      "|-----B|",
      "M =", missionaries_on_right,
      "C =", cannibals_on_right)

# %%
if missionaries < 0 or cannibals < 0:
    print("Invalid Move")

elif (missionaries + cannibals) < 1 or (missionaries + cannibals) > 2:
    print("Invalid Move")

# %%
if (missionaries_on_right < cannibals_on_right and missionaries_on_right > 0) or \
   (missionaries_on_left < cannibals_on_left and missionaries_on_left > 0):

    print("YOU LOSE")

# %%
if missionaries_on_left == 3 and cannibals_on_left == 3:
    print("YOU WIN")

# %%
from IPython.display import clear_output

boat_side = "Right"

missionaries_on_right = 3
cannibals_on_right = 3

missionaries_on_left = 0
cannibals_on_left = 0


def display():

    if boat_side == "Right":
        print(
            "M =", missionaries_on_left,
            "C =", cannibals_on_left,
            "|-----B|",
            "M =", missionaries_on_right,
            "C =", cannibals_on_right
        )
    else:
        print(
            "M =", missionaries_on_left,
            "C =", cannibals_on_left,
            "|B-----|",
            "M =", missionaries_on_right,
            "C =", cannibals_on_right
        )


display()

for i in range(1):

    missionaries = int(input("Enter number of missionaries (10 to quit): "))

    if missionaries == 10:
        print("Game Over")
        break

    cannibals = int(input("Enter number of cannibals: "))

    # Invalid input
    if missionaries < 0 or cannibals < 0:
        print("Invalid Move")
        continue

    # Boat can carry only 1 or 2 people
    if (missionaries + cannibals) < 1 or (missionaries + cannibals) > 2:
        print("Invalid Move")
        continue

    # Boat on Right Side
    if boat_side == "Right":

        if missionaries > missionaries_on_right:
            print("Invalid Move")
            continue

        if cannibals > cannibals_on_right:
            print("Invalid Move")
            continue

        missionaries_on_right -= missionaries
        cannibals_on_right -= cannibals

        missionaries_on_left += missionaries
        cannibals_on_left += cannibals

        boat_side = "Left"

    # Boat on Left Side
    else:

        if missionaries > missionaries_on_left:
            print("Invalid Move")
            continue

        if cannibals > cannibals_on_left:
            print("Invalid Move")
            continue

        missionaries_on_left -= missionaries
        cannibals_on_left -= cannibals

        missionaries_on_right += missionaries
        cannibals_on_right += cannibals

        boat_side = "Right"

    clear_output(wait=True)

    display()

    # Lose condition on left side
    if (missionaries_on_left > 0 and
            cannibals_on_left > missionaries_on_left):
        print("YOU LOSE")
        break

    # Lose condition on right side
    if (missionaries_on_right > 0 and
            cannibals_on_right > missionaries_on_right):
        print("YOU LOSE")
        break

    # Win condition
    if (missionaries_on_left == 3 and
            cannibals_on_left == 3):
        print("YOU WIN")
        break
# Out:
# M = 1 C = 1 |B-----| M = 2 C = 2

# %%
def display():

    ui = ""

    # Left missionaries
    for i in range(missionaries_on_left):
        ui += "💂"

    # Left cannibals
    for i in range(cannibals_on_left):
        ui += "👹"

    ui += "|"

    # River
    for i in range(5):
        ui += "🌊"

    # Boat position
    if boat_side == "Left":
        ui += "🚢"

    ui += "|"

    if boat_side == "Right":
        ui += "🚢"

    # Right missionaries
    for i in range(missionaries_on_right):
        ui += "💂"

    # Right cannibals
    for i in range(cannibals_on_right):
        ui += "👹"

    print(ui)
